# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/landscapes' '/content/'

# %%
import torch
torch.device("xpu") if torch.cuda.is_available() else torch.device("cpu")
# Out:
# False

# %%
# %run "/content/drive/My Drive/Colab Notebooks/Q1/main.py"
# Out:
# start reading images
# preprocessing has just finished
# ...
# 100%|██████████| 5/5 [01:44<00:00, 20.96s/it]
# [280.32925207124845, 273.5371537065396, 313.5625600484447, 234.68098474374818, 225.76466471824028]
# [263.04434732697024, 230.98062299415642, 226.2693705569789, 222.29238676639406, 217.77907828315577]

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/Q1/main.py"
# Out:
# start reading images
# libpng warning: iCCP: known incorrect sRGB profile
# preprocessing has just finished
# 0it [00:00, ?it/s]
# []
# []
# Figure(1000x1000)
